# %% [markdown]
# Polynomial Linear Regression

# %% [markdown]
# Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %% [markdown]
# Importing the dataset

# %%
dataset = pd.read_csv("dataset/Data.csv")
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# Training the linear regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# Training the polinomial regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# Visualising the Linear Regression Results

# %%
# plt.scatter(X, y, color="red")
# plt.plot(X, lin_reg.predict(X))
# plt.title("Truth or Bluff (Linear Regression)")
# plt.xlabel("Position Level")
# plt.ylabel("Salary")
# plt.grid()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 plt.scatter(X, y, color="red")
#       2 plt.plot(X, lin_reg.predict(X))
#       3 plt.title("Truth or Bluff (Linear Regression)")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\pyplot.py:2862, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2857 @_copy_docstring_and_deprecators(Axes.scatter)
#    2858 def scatter(
#    2859         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
# ...

# %% [markdown]
# Visualising the Polynomial Regression Results

# %%
# plt.scatter(X, y, color="red")
# plt.plot(X, lin_reg_2.predict(X_poly))
# plt.title("Truth or Bluff (Polynomial Regression)")
# plt.xlabel("Position Level")
# plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# Visualising the Polynomial Regression Results (for higher resolution ans smoother curve)

# %%
# x_dense = np.linspace(min(X), max(X), 100)
# plt.scatter(X, y, color="red")
# plt.plot(x_dense, lin_reg_2.predict(poly_reg.fit_transform(x_dense)))
# plt.title("Truth or Bluff (Polynomial Regression)")
# plt.xlabel("Position Level")
# plt.ylabel("Salary")
# plt.grid()

# %% [markdown]
# Predicting a new result with Linear Regression

# %%
# lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# Predicting a new result with Polynomial Regression

# %%
# lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265155])

# %% [markdown]
# Evaluating the Model Performace

# %%
from sklearn.metrics import r2_score
r2_score(y, lin_reg_2.predict(poly_reg.fit_transform(X)))
# Out:
# 0.9973922891706614
