# %% [markdown]
# # FUNDAMENTOS DE CIÊNCIA DE DADOS E INTELIGÊNCIA DE NEGÓCIOS
#
# ## Avaliação 1:
#
# ## Equipe:
#
#
# *   Robson dos santos sampaio - P23100456
# *   João Paulo Pinto Beserra - P23100372
# *   Ciro Ávila de Sousa - P23100365
# *   Ariclecio Cavalcanti Valenca Coutinho - P23100367

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1) Import dataframe Pinguins

# %%
url = 'https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv'
df = pd.read_csv(url)

# %% [markdown]
# ## 2) Análise

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %% [markdown]
# Chamar o head é interessante para dar visão das colunas e de seus elementos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %% [markdown]
# Alguns campos apresentam campos "NaN". Como não são muitos, iremos remover essas linhas do dataframe.

# %%
# Removendo as linhas com valores NaN
df_pinguin = df.dropna()

# %%
df_pinguin.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 4       3450.0  female  2007
# 5       3650.0    male  2007

# %%
df_pinguin.tail()
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009

# %% [markdown]
# ### Atraves do método tail nós percebemos que os indices não foram alterados automaticamente. Iremos então redefinir os índices

# %%
df_pinguin = df_pinguin.reset_index(drop=True)

# %%
df_pinguin
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen            36.7           19.3              193.0
# 4       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 328  Chinstrap      Dream            55.8           19.8              207.0
# 329  Chinstrap      Dream            43.5           18.1              202.0
# 330  Chinstrap      Dream            49.6           18.2              193.0
# 331  Chinstrap      Dream            50.8           19.0              210.0
# 332  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %% [markdown]
# ### Agora vamos analisar como está nosso dataframe

# %%
df_pinguin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
#  7   year               333 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 20.9+ KB

# %% [markdown]
# O info mostrou que nosso dataframe não tem mais valores NaN

# %%
df_pinguin.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   333.000000
# mean   2008.042042
# std       0.812944
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
# Contar a quantidade de cada espécie
count_sex = df_pinguin['sex'].value_counts()

# Configurar o estilo do Seaborn
sns.set(style="darkgrid")

# Plotar o gráfico de barras
plt.figure(figsize=(8, 6))
sns.barplot(x=count_sex.index, y=count_sex.values)
plt.title('Quantidade de cada sexo')
plt.xlabel('Sex')
plt.ylabel('Quantidade')
plt.show()

# %%
# Contar a quantidade de cada espécie
count_species = df_pinguin['species'].value_counts()

# Configurar o estilo do Seaborn
sns.set(style="darkgrid")

# Plotar o gráfico de barras
plt.figure(figsize=(8, 6))
sns.barplot(x=count_species.index, y=count_species.values)
plt.title('Quantidade de cada espécie')
plt.xlabel('Espécie')
plt.ylabel('Quantidade')
plt.show()

# %%
# Ordenar o DataFrame pela massa corporal em ordem decrescente
df_sorted = df_pinguin.sort_values('body_mass_g', ascending=False)

# Configurar o estilo do Seaborn
sns.set(style="darkgrid")

# Plotar o gráfico de barras horizontal
plt.figure(figsize=(8, 6))
sns.barplot(y='body_mass_g', x='species', data=df_sorted, hue='sex')
plt.title('Espécies com Maior Massa Corporal')
plt.ylabel('Massa Corporal')
plt.xlabel('Espécie')
plt.show()

# %% [markdown]
# ### Correlação entre as variáveis

# %%
df_pinguin.corr()
# Out:
# <ipython-input-185-41cc541449b2>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_pinguin.corr()
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
# year                     0.032657      -0.048182           0.151068
#
#                    body_mass_g      year
# bill_length_mm        0.589451  0.032657
# bill_depth_mm        -0.472016 -0.048182
# flipper_length_mm     0.872979  0.151068
# body_mass_g           1.000000  0.021862
# year                  0.021862  1.000000

# %% [markdown]
# Através do método corr percebemos que as maiores correlações são
#
# * body_mass_g x flipper_lenght_mm
# * body_mass_g x bill_lenght_mm
# * bill_lenght_mm x flipper_lenght_mm

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 6))
g1 = sns.regplot(data=df_pinguin, x='body_mass_g', y='flipper_length_mm', ax=ax1)
g2 = sns.regplot(data=df_pinguin, x='flipper_length_mm', y='bill_length_mm', ax=ax2)
g3 = sns.regplot(data=df_pinguin, x='body_mass_g', y='bill_length_mm', ax=ax3)

g1.set_title('Corr massa corporal x tamanho nadadeira')
g2.set_title('Corr tamanho bico x tamanho nadadeira')
g3.set_title('Corr massa corporal x tamanho bico')
# Out:
# Text(0.5, 1.0, 'Corr massa corporal x tamanho bico')

# %%
sns.jointplot(data=df_pinguin, x='body_mass_g', y='flipper_length_mm', kind='reg')

# %%
sns.jointplot(data=df_pinguin, x='bill_length_mm', y='flipper_length_mm', kind='reg')

# %%
sns.jointplot(data=df_pinguin, y='bill_length_mm', x='body_mass_g', kind='reg')

# %%
sns.relplot(data=df_pinguin, x='bill_length_mm', y='flipper_length_mm', hue='island', style='species')

# %%
sns.relplot(data=df_pinguin, x='body_mass_g', y='flipper_length_mm', hue='island', style='species' )

# %%
sns.relplot(data=df_pinguin, x='body_mass_g', y='bill_length_mm', hue='island', style='species' )

# %% [markdown]
# Esses três foram os melhores gráficos. Eles mostram que os pinguins com bico e barbatana maiores são de uma espécie específica e estão, em sua maioria, em uma ilha específica. Também podemos ver que esses mesmo pinguins têm mais massa corporal. Isso pode ser devido ao seu bico avantajado que facilita na hora da caça. A sua barbatana mais alongada também ajudaria na sua sobrevivência.

# %%
def gera_lista(valor_min: float , valor_max: float, 
               quant_total: int, casa_dec:int) -> list:
  """
    Cria uma lista aleátoria de N números com base em valores
    minimo e máximo.
    Arguments:
        valor_min: an float
        valor_max: an float
        quant_total: an integer
        casa_dec: an integer
    Returns:
        Uma lista com quant_total de números aleátorios.
    """

  import random
  
  random_floats = [round(random.uniform(valor_min, valor_max), 
                         casa_dec) for _ in range(quant_total)]

  return random_floats

# %%
valor_min_bill_lenght = df_pinguin['bill_length_mm'].min()
valor_min_bill_depth = df_pinguin['bill_depth_mm'].min()
valor_min_flipper = df_pinguin['flipper_length_mm'].min()
valor_min_mass = df_pinguin['body_mass_g'].min()

# %%
valor_max_bill_lenght = df_pinguin['bill_length_mm'].max()
valor_max_bill_depth = df_pinguin['bill_depth_mm'].max()
valor_max_flipper = df_pinguin['flipper_length_mm'].max()
valor_max_mass = df_pinguin['body_mass_g'].max()

# %%
lis_bill_lenght = gera_lista(valor_min_bill_lenght, valor_max_bill_lenght, 4500, 2)
lis_bill_depth = gera_lista(valor_min_bill_depth, valor_max_bill_depth, 4500, 2)
lis_flipper = gera_lista(valor_min_flipper, valor_max_flipper, 4500, 2)
lis_mass = gera_lista(valor_min_mass, valor_max_mass, 4500, 2)

# %%
df_pinguin.head(n=1)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
#
#    body_mass_g   sex  year
# 0       3750.0  male  2007

# %% [markdown]
# Estou trocando o noome das colunas do df_pinguin para que sejam as mesmas que as do novo dataframe

# %%
nome_das_colunas = ['especie', 'ilha', 'bico_comp', 'bico_larg', 'nadadeira_comp', 'mass_corp', 'sexo', 'ano']

# %%
df_novo = pd.DataFrame(columns=nome_das_colunas)

# %%
df_novo['bico_comp'] = lis_bill_lenght
df_novo['bico_larg'] = lis_bill_depth
df_novo['nadadeira_comp'] = lis_flipper
df_novo['mass_corp'] = lis_mass

# %%
df_novo
# Out:
#      especie ilha  bico_comp  bico_larg  nadadeira_comp  mass_corp sexo  ano
# 0        NaN  NaN      45.39      13.34          227.52    2826.08  NaN  NaN
# 1        NaN  NaN      45.35      18.88          207.30    5104.09  NaN  NaN
# 2        NaN  NaN      47.40      20.45          193.53    4890.33  NaN  NaN
# 3        NaN  NaN      34.38      13.70          180.56    4583.50  NaN  NaN
# 4        NaN  NaN      32.83      14.05          224.35    4989.22  NaN  NaN
# ...      ...  ...        ...        ...             ...        ...  ...  ...
# 4495     NaN  NaN      52.40      13.96          213.47    4558.09  NaN  NaN
# 4496     NaN  NaN      46.20      16.37          210.70    4827.42  NaN  NaN
# 4497     NaN  NaN      47.71      17.25          218.82    3214.71  NaN  NaN
# 4498     NaN  NaN      33.06      15.68          213.25    3017.81  NaN  NaN
# 4499     NaN  NaN      39.11      17.97          219.49    2715.33  NaN  NaN
#
# [4500 rows x 8 columns]

# %%
df_pinguin.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year'],
#       dtype='object')

# %%
mapeamento = {'species': 'especie',
              'island': 'ilha',
              'bill_length_mm': 'bico_comp',
              'bill_depth_mm': 'bico_larg',
              'flipper_length_mm': 'nadadeira_comp',
              'body_mass_g': 'mass_corp',
              'sex': 'sexo',
              'year': 'ano'}

# %%
df_pinguin = df_pinguin.rename(columns=mapeamento)

# %%
dfs = [df_pinguin, df_novo]
df_concat = pd.concat(dfs, axis=0, ignore_index=True)

# %%
df_concat
# Out:
#      especie       ilha  bico_comp  bico_larg  nadadeira_comp  mass_corp  \
# 0     Adelie  Torgersen      39.10      18.70          181.00    3750.00
# 1     Adelie  Torgersen      39.50      17.40          186.00    3800.00
# 2     Adelie  Torgersen      40.30      18.00          195.00    3250.00
# 3     Adelie  Torgersen      36.70      19.30          193.00    3450.00
# 4     Adelie  Torgersen      39.30      20.60          190.00    3650.00
# ...      ...        ...        ...        ...             ...        ...
# 4828     NaN        NaN      52.40      13.96          213.47    4558.09
# 4829     NaN        NaN      46.20      16.37          210.70    4827.42
# 4830     NaN        NaN      47.71      17.25          218.82    3214.71
# 4831     NaN        NaN      33.06      15.68          213.25    3017.81
# 4832     NaN        NaN      39.11      17.97          219.49    2715.33
#
#         sexo   ano
# 0       male  2007
# 1     female  2007
# 2     female  2007
# ...

# %%
df_concat.corr()
# Out:
# <ipython-input-207-26fdf3a4e505>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_concat.corr()
#                 bico_comp  bico_larg  nadadeira_comp  mass_corp
# bico_comp        1.000000  -0.013821        0.034362   0.029096
# bico_larg       -0.013821   1.000000       -0.029477  -0.012426
# nadadeira_comp   0.034362  -0.029477        1.000000   0.032863
# mass_corp        0.029096  -0.012426        0.032863   1.000000

# %%
df_concat.describe()
# Out:
#          bico_comp    bico_larg  nadadeira_comp    mass_corp
# count  4833.000000  4833.000000      4833.00000  4833.000000
# mean     45.717786    17.298597       201.31223  4482.485640
# std       7.780560     2.390331        16.77816  1034.096877
# min      32.100000    13.100000       172.00000  2700.000000
# 25%      39.020000    15.250000       187.00000  3580.840000
# 50%      45.560000    17.330000       201.46000  4489.570000
# 75%      52.370000    19.310000       215.67000  5367.840000
# max      59.600000    21.500000       231.00000  6300.000000

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 6))
g1 = sns.regplot(data=df_concat, x='mass_corp', y='nadadeira_comp', ax=ax1)
g2 = sns.regplot(data=df_concat, x='nadadeira_comp', y='bico_larg', ax=ax2)
g3 = sns.regplot(data=df_concat, x='mass_corp', y='bico_larg', ax=ax3)

g1.set_title('Corr massa corporal x tamanho nadadeira')
g2.set_title('Corr tamanho bico x tamanho nadadeira')
g3.set_title('Corr massa corporal x tamanho bico')
# Out:
# Text(0.5, 1.0, 'Corr massa corporal x tamanho bico')

# %% [markdown]
# As muitas incidências de NaN não permitem uma análise correta dos dados. Entretanto, técnicas de machine learning poderiam ser usadas para popular os dados faltantes

# %%
df_merge_left = df_pinguin.merge(df_novo, how='left', on='especie')
df_merge_right = df_pinguin.merge(df_novo, how='right', on='especie')
df_merge_inner = df_pinguin.merge(df_novo, how='inner', on='especie')
df_merge_outer = df_pinguin.merge(df_novo, how='outer', on='especie')
df_merge_cross = df_pinguin.merge(df_novo, how='cross')
# Out:
# <ipython-input-211-00ddbecc6cc6>:2: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   df_merge_right = df_pinguin.merge(df_novo, how='right', on='especie')

# %%
df_merge_left.corr()
# Out:
# <ipython-input-214-39525858422f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_merge_left.corr()
#                   bico_comp_x  bico_larg_x  nadadeira_comp_x  mass_corp_x  \
# bico_comp_x          1.000000    -0.228626          0.653096     0.589451
# bico_larg_x         -0.228626     1.000000         -0.577792    -0.472016
# nadadeira_comp_x     0.653096    -0.577792          1.000000     0.872979
# mass_corp_x          0.589451    -0.472016          0.872979     1.000000
# ano_x                0.032657    -0.048182          0.151068     0.021862
# bico_comp_y               NaN          NaN               NaN          NaN
# bico_larg_y               NaN          NaN               NaN          NaN
# nadadeira_comp_y          NaN          NaN               NaN          NaN
# ...

# %%
df_merge_right.corr()
# Out:
# <ipython-input-215-0eb611b10364>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_merge_right.corr()
#                   bico_comp_x  bico_larg_x  nadadeira_comp_x  mass_corp_x  \
# bico_comp_x               NaN          NaN               NaN          NaN
# bico_larg_x               NaN          NaN               NaN          NaN
# nadadeira_comp_x          NaN          NaN               NaN          NaN
# mass_corp_x               NaN          NaN               NaN          NaN
# ano_x                     NaN          NaN               NaN          NaN
# bico_comp_y               NaN          NaN               NaN          NaN
# bico_larg_y               NaN          NaN               NaN          NaN
# nadadeira_comp_y          NaN          NaN               NaN          NaN
# ...

# %%
df_merge_inner.corr()
# Out:
# <ipython-input-216-27a9c794e21a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_merge_inner.corr()
#                   bico_comp_x  bico_larg_x  nadadeira_comp_x  mass_corp_x  \
# bico_comp_x               NaN          NaN               NaN          NaN
# bico_larg_x               NaN          NaN               NaN          NaN
# nadadeira_comp_x          NaN          NaN               NaN          NaN
# mass_corp_x               NaN          NaN               NaN          NaN
# ano_x                     NaN          NaN               NaN          NaN
# bico_comp_y               NaN          NaN               NaN          NaN
# bico_larg_y               NaN          NaN               NaN          NaN
# nadadeira_comp_y          NaN          NaN               NaN          NaN
# ...

# %%
df_merge_outer.corr()
# Out:
# <ipython-input-217-069751e268a8>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_merge_outer.corr()
#                   bico_comp_x  bico_larg_x  nadadeira_comp_x  mass_corp_x  \
# bico_comp_x          1.000000    -0.228626          0.653096     0.589451
# bico_larg_x         -0.228626     1.000000         -0.577792    -0.472016
# nadadeira_comp_x     0.653096    -0.577792          1.000000     0.872979
# mass_corp_x          0.589451    -0.472016          0.872979     1.000000
# ano_x                0.032657    -0.048182          0.151068     0.021862
# bico_comp_y               NaN          NaN               NaN          NaN
# bico_larg_y               NaN          NaN               NaN          NaN
# nadadeira_comp_y          NaN          NaN               NaN          NaN
# ...

# %%
df_merge_cross.corr()
# Out:
# <ipython-input-218-ff575738f6a8>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_merge_cross.corr()
#                    bico_comp_x   bico_larg_x  nadadeira_comp_x   mass_corp_x  \
# bico_comp_x       1.000000e+00 -2.286256e-01      6.530956e-01  5.894511e-01
# bico_larg_x      -2.286256e-01  1.000000e+00     -5.777917e-01 -4.720157e-01
# nadadeira_comp_x  6.530956e-01 -5.777917e-01      1.000000e+00  8.729789e-01
# mass_corp_x       5.894511e-01 -4.720157e-01      8.729789e-01  1.000000e+00
# ano_x             3.265690e-02 -4.818160e-02      1.510679e-01  2.186213e-02
# bico_comp_y      -1.415344e-13  4.352846e-14     -8.053769e-14 -4.669440e-14
# bico_larg_y      -6.476006e-14  9.032271e-14     -9.257554e-14 -6.517245e-14
# nadadeira_comp_y  3.859535e-14 -8.050599e-14      8.066436e-14  5.847744e-14
# ...

# %% [markdown]
# ### Aparentemente o merge concat foi a melhor forma de juntar os dataframes
